# %% [markdown]
# # Method 1 : using ![title]
# #### First, change cell to Markdown and type the line hashed below

# %%
###  (![title](test.png))

# %% [markdown]
# ![title](test.png)

# %% [markdown]
# # Method 2 : using Image from IPython

# %%
from IPython.display import Image
Image(filename="test.png")

# %%
Image(filename="../test/test.png") #loading file in different folder works

# %% [markdown]
# # Method 3 : using html syntax
# #### First, change cell to Markdown and type any of the lines hashed below

# %% [markdown]
# # <img src = "test.png " />
#
# # <img src = "test.png " style="height:50px" />
# # <img src = "../test/test.png " />

# %% [markdown]
# <img src = "test.png " />

# %% [markdown]
# <img src = "test.png " style="height:50px" />

# %% [markdown]
# <img src = "../test/test.png " />

# %% [markdown]
# # Method 4 : using html syntax II

# %%
# %%html
# <img src = "test.png ", width=60 height=60/>
# Out:
# <img src = "test.png ", width=60 height=60/>

# %%
# %%html
# <img src = "../test/test.png ", width=60 height=60/> #image in separate folder
# Out:
# <img src = "../test/test.png ", width=60 height=60/>

# %%
# %%html
# <img src = "test.png ", style= "height=60"/>
# Out:
# <img src = "test.png ", style= "height=60"/>

# %% [markdown]
# <img src = "test.png "/>
